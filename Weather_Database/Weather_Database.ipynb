# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | ayan
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | liku
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | shubarkuduk
# Processing Record 13 of Set 1 | nuevo progreso
# Processing Record 14 of Set 1 | mao
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | vila franca do campo
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | makakilo city
# Processing Record 19 of Set 1 | adrar
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | la ronge
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | svetlogorsk
# Processing Record 28 of Set 1 | murray bridge
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | imbituba
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | tautira
# Processing Record 33 of Set 1 | vestmannaeyjar
# Processing Record 34 of Set 1 | dauphin
# Processing Record 35 of Set 1 | hakkari
# Processing Record 36 of Set 1 | sioux lookout
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | casian
# Processing Record 39 of Set 1 | asau
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | vardo
# Processing Record 42 of Set 1 | kudahuvadhoo
# Processing Record 43 of Set 1 | umm kaddadah
# Processing Record 44 of Set 1 | tabuk
# Processing Record 45 of Set 1 | bandar-e lengeh
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | shache
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | severo-kurilsk
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | salinopolis
# Processing Record 6 of Set 2 | port hardy
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | tura
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | kavieng
# Processing Record 12 of Set 2 | ostrovnoy
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | santa ana
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 2 | hovd
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | inhambane
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | charters towers
# Processing Record 28 of Set 2 | sooke
# Processing Record 29 of Set 2 | birobidzhan
# Processing Record 30 of Set 2 | taurage
# Processing Record 31 of Set 2 | flin flon
# Processing Record 32 of Set 2 | santa fe
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | polovinnoye
# Processing Record 37 of Set 2 | manoel urbano
# Processing Record 38 of Set 2 | cabra
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | muisne
# Processing Record 42 of Set 2 | alice springs
# Processing Record 43 of Set 2 | komsomolskiy
# Processing Record 44 of Set 2 | yining
# Processing Record 45 of Set 2 | la rioja
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | ginda
# Processing Record 49 of Set 2 | rio blanco
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | turinsk
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | atikokan
# Processing Record 5 of Set 3 | chapada dos guimaraes
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | finschhafen
# Processing Record 9 of Set 3 | paracuru
# Processing Record 10 of Set 3 | touros
# Processing Record 11 of Set 3 | ocoee
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 3 | tarabha
# Processing Record 15 of Set 3 | harper
# Processing Record 16 of Set 3 | ternate
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | maltahohe
# Processing Record 20 of Set 3 | osa
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | mahajanga
# Processing Record 24 of Set 3 | marzuq
# Processing Record 25 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 3 | zhangye
# Processing Record 27 of Set 3 | shakawe
# Processing Record 28 of Set 3 | buin
# Processing Record 29 of Set 3 | nurota
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | katherine
# Processing Record 33 of Set 3 | eureka
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | hami
# Processing Record 38 of Set 3 | coruripe
# Processing Record 39 of Set 3 | moron
# Processing Record 40 of Set 3 | prince rupert
# Processing Record 41 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | new norfolk
# Processing Record 44 of Set 3 | mokhsogollokh
# Processing Record 45 of Set 3 | kahului
# Processing Record 46 of Set 3 | glendive
# Processing Record 47 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | tasiilaq
# Processing Record 50 of Set 3 | preobrazheniye
# Processing Record 1 of Set 4 | isagarh
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | arman
# Processing Record 8 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 9 of Set 4 | komatipoort
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | turayf
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | batagay
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | vanimo
# Processing Record 16 of Set 4 | sao joao de pirabas
# Processing Record 17 of Set 4 | diffa
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | karachi
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | qrendi
# Processing Record 24 of Set 4 | sayanskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | viransehir
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | hobart
# Processing Record 28 of Set 4 | alindao
# Processing Record 29 of Set 4 | umm lajj
# Processing Record 30 of Set 4 | nargana
# Processing Record 31 of Set 4 | puerto escondido
# Processing Record 32 of Set 4 | bathsheba
# Processing Record 33 of Set 4 | whitehorse
# Processing Record 34 of Set 4 | ushtobe
# Processing Record 35 of Set 4 | olot
# Processing Record 36 of Set 4 | bereda
# Processing Record 37 of Set 4 | paamiut
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | bluff
# Processing Record 40 of Set 4 | georgetown
# Processing Record 41 of Set 4 | forecariah
# Processing Record 42 of Set 4 | culpeper
# Processing Record 43 of Set 4 | kedrovyy
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | shu
# Processing Record 46 of Set 4 | oranjestad
# Processing Record 47 of Set 4 | cascais
# Processing Record 48 of Set 4 | tezu
# Processing Record 49 of Set 4 | betong
# Processing Record 50 of Set 4 | changli
# Processing Record 1 of Set 5 | benghazi
# Processing Record 2 of Set 5 | nanortalik
# Processing Record 3 of Set 5 | martapura
# Processing Record 4 of Set 5 | xuddur
# Processing Record 5 of Set 5 | margate
# Processing Record 6 of Set 5 | flinders
# Processing Record 7 of Set 5 | meulaboh
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | pyapon
# Processing Record 10 of Set 5 | katha
# City not found. Skipping...
# Processing Record 11 of Set 5 | kostomuksha
# Processing Record 12 of Set 5 | santa isabel do rio negro
# Processing Record 13 of Set 5 | krasnoarmeysk
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | olafsvik
# Processing Record 16 of Set 5 | bambous virieux
# Processing Record 17 of Set 5 | gunupur
# Processing Record 18 of Set 5 | farafangana
# Processing Record 19 of Set 5 | tilichiki
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | acarau
# Processing Record 22 of Set 5 | terrace bay
# Processing Record 23 of Set 5 | iskateley
# Processing Record 24 of Set 5 | mount gambier
# Processing Record 25 of Set 5 | atbasar
# Processing Record 26 of Set 5 | hays
# Processing Record 27 of Set 5 | quang ngai
# Processing Record 28 of Set 5 | loiza
# Processing Record 29 of Set 5 | surt
# Processing Record 30 of Set 5 | oktyabrskoye
# Processing Record 31 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 5 | fujinomiya
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 5 | saint-jean-de-maurienne
# Processing Record 37 of Set 5 | cuamba
# Processing Record 38 of Set 5 | gat
# Processing Record 39 of Set 5 | nyagan
# Processing Record 40 of Set 5 | santa luzia
# Processing Record 41 of Set 5 | kassala
# Processing Record 42 of Set 5 | luangwa
# Processing Record 43 of Set 5 | ouesso
# Processing Record 44 of Set 5 | ust-nera
# Processing Record 45 of Set 5 | seoul
# Processing Record 46 of Set 5 | wake forest
# Processing Record 47 of Set 5 | sembe
# Processing Record 48 of Set 5 | anadyr
# Processing Record 49 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 50 of Set 5 | pachino
# Processing Record 1 of Set 6 | apache junction
# Processing Record 2 of Set 6 | russell
# Processing Record 3 of Set 6 | el zapote
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | harrismith
# Processing Record 6 of Set 6 | acajutla
# Processing Record 7 of Set 6 | tzucacab
# Processing Record 8 of Set 6 | kasama
# Processing Record 9 of Set 6 | sawakin
# Processing Record 10 of Set 6 | derzhavinsk
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | saskylakh
# Processing Record 13 of Set 6 | port lincoln
# Processing Record 14 of Set 6 | mayor pablo lagerenza
# Processing Record 15 of Set 6 | kangaatsiaq
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | takoradi
# Processing Record 18 of Set 6 | carlyle
# Processing Record 19 of Set 6 | arimalam
# Processing Record 20 of Set 6 | panama city
# Processing Record 21 of Set 6 | mecca
# Processing Record 22 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | albesti
# Processing Record 25 of Set 6 | sorong
# Processing Record 26 of Set 6 | grindavik
# Processing Record 27 of Set 6 | issia
# Processing Record 28 of Set 6 | kampene
# Processing Record 29 of Set 6 | talara
# Processing Record 30 of Set 6 | gazli
# Processing Record 31 of Set 6 | broken hill
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | ponta delgada
# Processing Record 35 of Set 6 | banmankhi
# Processing Record 36 of Set 6 | mundo nuevo
# Processing Record 37 of Set 6 | mbour
# Processing Record 38 of Set 6 | grand-santi
# Processing Record 39 of Set 6 | dedougou
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | jumla
# Processing Record 42 of Set 6 | pauini
# Processing Record 43 of Set 6 | higuey
# City not found. Skipping...
# Processing Record 44 of Set 6 | teixoso
# Processing Record 45 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 6 | gushikawa
# Processing Record 47 of Set 6 | octeville
# Processing Record 48 of Set 6 | abu samrah
# Processing Record 49 of Set 6 | honningsvag
# Processing Record 50 of Set 6 | bundaberg
# Processing Record 1 of Set 7 | victoria point
# Processing Record 2 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 7 | vao
# Processing Record 4 of Set 7 | beltiug
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | auki
# Processing Record 7 of Set 7 | yamada
# Processing Record 8 of Set 7 | taltal
# Processing Record 9 of Set 7 | ca mau
# Processing Record 10 of Set 7 | jalaun
# Processing Record 11 of Set 7 | tiarei
# Processing Record 12 of Set 7 | khash
# Processing Record 13 of Set 7 | dong hoi
# Processing Record 14 of Set 7 | porbandar
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | darab
# Processing Record 17 of Set 7 | padang
# Processing Record 18 of Set 7 | constitucion
# Processing Record 19 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 7 | san patricio
# Processing Record 21 of Set 7 | katangli
# Processing Record 22 of Set 7 | sandpoint
# Processing Record 23 of Set 7 | abu dhabi
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | vila velha
# Processing Record 26 of Set 7 | wladyslawowo
# Processing Record 27 of Set 7 | karratha
# Processing Record 28 of Set 7 | pinotepa nacional
# Processing Record 29 of Set 7 | hazorasp
# Processing Record 30 of Set 7 | sabang
# Processing Record 31 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 7 | cartagena del chaira
# Processing Record 33 of Set 7 | huarmey
# Processing Record 34 of Set 7 | katsuura
# Processing Record 35 of Set 7 | nakusp
# Processing Record 36 of Set 7 | manokwari
# Processing Record 37 of Set 7 | caraquet
# Processing Record 38 of Set 7 | dayong
# Processing Record 39 of Set 7 | shwebo
# Processing Record 40 of Set 7 | port augusta
# Processing Record 41 of Set 7 | punta umbria
# Processing Record 42 of Set 7 | eyl
# Processing Record 43 of Set 7 | east wenatchee bench
# Processing Record 44 of Set 7 | evora
# Processing Record 45 of Set 7 | palmer
# Processing Record 46 of Set 7 | salalah
# Processing Record 47 of Set 7 | uvalde
# Processing Record 48 of Set 7 | yerofey pavlovich
# Processing Record 49 of Set 7 | port-cartier
# Processing Record 50 of Set 7 | batemans bay
# Processing Record 1 of Set 8 | kurchum
# Processing Record 2 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 8 | cortez
# Processing Record 4 of Set 8 | burica
# City not found. Skipping...
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | kupang
# Processing Record 7 of Set 8 | manavalakurichi
# Processing Record 8 of Set 8 | bethanien
# Processing Record 9 of Set 8 | springbok
# Processing Record 10 of Set 8 | ayolas
# Processing Record 11 of Set 8 | riyadh
# Processing Record 12 of Set 8 | nouakchott
# Processing Record 13 of Set 8 | hualmay
# Processing Record 14 of Set 8 | kandrian
# Processing Record 15 of Set 8 | rozkishne
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | labuhan
# Processing Record 18 of Set 8 | skibbereen
# Processing Record 19 of Set 8 | laguna
# Processing Record 20 of Set 8 | gari
# Processing Record 21 of Set 8 | benicarlo
# Processing Record 22 of Set 8 | bondoukou
# Processing Record 23 of Set 8 | zyryanovsk
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | methoni
# Processing Record 26 of Set 8 | kaele
# Processing Record 27 of Set 8 | kannangad
# Processing Record 28 of Set 8 | shingu
# Processing Record 29 of Set 8 | isangel
# Processing Record 30 of Set 8 | taoudenni
# Processing Record 31 of Set 8 | pozzallo
# Processing Record 32 of Set 8 | marion
# Processing Record 33 of Set 8 | ambilobe
# Processing Record 34 of Set 8 | ilulissat
# Processing Record 35 of Set 8 | norfolk
# Processing Record 36 of Set 8 | beloha
# Processing Record 37 of Set 8 | tres arroyos
# Processing Record 38 of Set 8 | urumqi
# Processing Record 39 of Set 8 | xai-xai
# Processing Record 40 of Set 8 | avera
# Processing Record 41 of Set 8 | louis trichardt
# Processing Record 42 of Set 8 | kaeo
# Processing Record 43 of Set 8 | quelimane
# Processing Record 44 of Set 8 | orange
# Processing Record 45 of Set 8 | anaconda
# Processing Record 46 of Set 8 | aykhal
# Processing Record 47 of Set 8 | matagami
# Processing Record 48 of Set 8 | olive branch
# Processing Record 49 of Set 8 | linxia
# Processing Record 50 of Set 8 | saint-francois
# Processing Record 1 of Set 9 | nioro
# Processing Record 2 of Set 9 | kayes
# Processing Record 3 of Set 9 | beberibe
# Processing Record 4 of Set 9 | ixtapa
# Processing Record 5 of Set 9 | baie-comeau
# Processing Record 6 of Set 9 | zaysan
# Processing Record 7 of Set 9 | merauke
# Processing Record 8 of Set 9 | benjamin hill
# Processing Record 9 of Set 9 | nemuro
# Processing Record 10 of Set 9 | mehamn
# Processing Record 11 of Set 9 | yalutorovsk
# Processing Record 12 of Set 9 | santo amaro da imperatriz
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | marsh harbour
# Processing Record 15 of Set 9 | moskovskiy
# Processing Record 16 of Set 9 | himora
# City not found. Skipping...
# Processing Record 17 of Set 9 | saint-augustin
# Processing Record 18 of Set 9 | liberia
# Processing Record 19 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 9 | simbahan
# Processing Record 21 of Set 9 | rocha
# Processing Record 22 of Set 9 | pangnirtung
# Processing Record 23 of Set 9 | teya
# Processing Record 24 of Set 9 | san borja
# Processing Record 25 of Set 9 | namatanai
# Processing Record 26 of Set 9 | lata
# Processing Record 27 of Set 9 | mitu
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | pangai
# Processing Record 30 of Set 9 | narauli
# Processing Record 31 of Set 9 | yumaguzino
# Processing Record 32 of Set 9 | antofagasta
# Processing Record 33 of Set 9 | nishihara
# Processing Record 34 of Set 9 | oktyabrskiy
# Processing Record 35 of Set 9 | verkhnevilyuysk
# Processing Record 36 of Set 9 | ismaning
# Processing Record 37 of Set 9 | dunedin
# Processing Record 38 of Set 9 | nalut
# Processing Record 39 of Set 9 | kampong thum
# Processing Record 40 of Set 9 | weinan
# Processing Record 41 of Set 9 | coronado
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | broome
# Processing Record 44 of Set 9 | mahibadhoo
# Processing Record 45 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 46 of Set 9 | chapais
# Processing Record 47 of Set 9 | narsaq
# Processing Record 48 of Set 9 | matane
# Processing Record 49 of Set 9 | olinda
# Processing Record 50 of Set 9 | kruisfontein
# Processing Record 1 of Set 10 | san nicolas
# Processing Record 2 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 10 | tshela
# Processing Record 4 of Set 10 | anshun
# Processing Record 5 of Set 10 | takapau
# Processing Record 6 of Set 10 | aguimes
# Processing Record 7 of Set 10 | makat
# Processing Record 8 of Set 10 | manjeshwar
# Processing Record 9 of Set 10 | gasa
# Processing Record 10 of Set 10 | the valley
# Processing Record 11 of Set 10 | vawkavysk
# Processing Record 12 of Set 10 | pacific grove
# Processing Record 13 of Set 10 | klyuchi
# Processing Record 14 of Set 10 | arauco
# Processing Record 15 of Set 10 | leningradskiy
# Processing Record 16 of Set 10 | san matias
# Processing Record 17 of Set 10 | tuatapere
# Processing Record 18 of Set 10 | dembi dolo
# Processing Record 19 of Set 10 | souillac
# Processing Record 20 of Set 10 | tomatlan
# Processing Record 21 of Set 10 | malmesbury
# Processing Record 22 of Set 10 | nigde
# Processing Record 23 of Set 10 | oliver
# Processing Record 24 of Set 10 | dharchula
# Processing Record 25 of Set 10 | baruun-urt
# Processing Record 26 of Set 10 | banda aceh
# Processing Record 27 of Set 10 | trapani
# Processing Record 28 of Set 10 | zwedru
# Processing Record 29 of Set 10 | champerico
# Processing Record 30 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 31 of Set 10 | urucara
# Processing Record 32 of Set 10 | goure
# Processing Record 33 of Set 10 | samarai
# Processing Record 34 of Set 10 | antalaha
# Processing Record 35 of Set 10 | westport
# Processing Record 36 of Set 10 | guilin
# Processing Record 37 of Set 10 | khandyga
# Processing Record 38 of Set 10 | bacolod
# Processing Record 39 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 10 | voh
# Processing Record 41 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 10 | garowe
# Processing Record 43 of Set 10 | raigarh
# Processing Record 44 of Set 10 | grand gaube
# Processing Record 45 of Set 10 | yumen
# Processing Record 46 of Set 10 | hickory
# Processing Record 47 of Set 10 | cabedelo
# Processing Record 48 of Set 10 | port blair
# Processing Record 49 of Set 10 | villa vazquez
# City not found. Skipping...
# Processing Record 50 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 11 | zaranj
# Processing Record 2 of Set 11 | gravdal
# Processing Record 3 of Set 11 | wick
# Processing Record 4 of Set 11 | mackenzie
# Processing Record 5 of Set 11 | appleton
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | tommot
# Processing Record 8 of Set 11 | la tuque
# Processing Record 9 of Set 11 | swan hill
# Processing Record 10 of Set 11 | sept-iles
# Processing Record 11 of Set 11 | llanes
# Processing Record 12 of Set 11 | jaciara
# Processing Record 13 of Set 11 | dudinka
# Processing Record 14 of Set 11 | senneterre
# Processing Record 15 of Set 11 | bac lieu
# Processing Record 16 of Set 11 | nabire
# Processing Record 17 of Set 11 | aitape
# Processing Record 18 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | zhigansk
# Processing Record 21 of Set 11 | bambanglipuro
# Processing Record 22 of Set 11 | garissa
# Processing Record 23 of Set 11 | nelson bay
# Processing Record 24 of Set 11 | morondava
# Processing Record 25 of Set 11 | guerrero negro
# Processing Record 26 of Set 11 | lahaina
# Processing Record 27 of Set 11 | mariakani
# Processing Record 28 of Set 11 | dingle
# Processing Record 29 of Set 11 | saint george
# Processing Record 30 of Set 11 | hede
# Processing Record 31 of Set 11 | turukhansk
# Processing Record 32 of Set 11 | pella
# Processing Record 33 of Set 11 | tessalit
# Processing Record 34 of Set 11 | staffanstorp
# Processing Record 35 of Set 11 | ahuimanu
# Processing Record 36 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 11 | acapulco
# Processing Record 38 of Set 11 | ducheng
# Processing Record 39 of Set 11 | san jose
# Processing Record 40 of Set 11 | atasu
# Processing Record 41 of Set 11 | husavik
# Processing Record 42 of Set 11 | joao camara
# Processing Record 43 of Set 11 | zihuatanejo
# Processing Record 44 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 45 of Set 11 | lagoa
# Processing Record 46 of Set 11 | ottawa
# Processing Record 47 of Set 11 | kautokeino
# Processing Record 48 of Set 11 | primorskiy
# Processing Record 49 of Set 11 | havre-saint-pierre
# Processing Record 50 of Set 11 | usinsk
# Processing Record 1 of Set 12 | havoysund
# Processing Record 2 of Set 12 | moshenskoye
# Processing Record 3 of Set 12 | beringovskiy
# Processing Record 4 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 12 | moindou
# Processing Record 6 of Set 12 | virginia beach
# Processing Record 7 of Set 12 | necochea
# Processing Record 8 of Set 12 | college
# Processing Record 9 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 12 | port hedland
# Processing Record 11 of Set 12 | saint-georges
# Processing Record 12 of Set 12 | caraballeda
# Processing Record 13 of Set 12 | half moon bay
# Processing Record 14 of Set 12 | channel-port aux basques
# Processing Record 15 of Set 12 | hun
# Processing Record 16 of Set 12 | gizo
# Processing Record 17 of Set 12 | fort-shevchenko
# Processing Record 18 of Set 12 | indramayu
# Processing Record 19 of Set 12 | marechal candido rondon
# Processing Record 20 of Set 12 | xichang
# Processing Record 21 of Set 12 | jishou
# Processing Record 22 of Set 12 | sao felix do xingu
# Processing Record 23 of Set 12 | sola
# Processing Record 24 of Set 12 | qasigiannguit
# Processing Record 25 of Set 12 | baykit
# Processing Record 26 of Set 12 | lompoc
# Processing Record 27 of Set 12 | vaitape
# Processing Record 28 of Set 12 | shimoda
# Processing Record 29 of Set 12 | takaka
# Processing Record 30 of Set 12 | kilmez
# City not found. Skipping...
# Processing Record 31 of Set 12 | cairns
# Processing Record 32 of Set 12 | nieves
# Processing Record 33 of Set 12 | korla
# Processing Record 34 of Set 12 | zeya
# Processing Record 35 of Set 12 | yenagoa
# Processing Record 36 of Set 12 | poum
# Processing Record 37 of Set 12 | alofi
# Processing Record 38 of Set 12 | juegang
# Processing Record 39 of Set 12 | barpeta
# Processing Record 40 of Set 12 | ola
# Processing Record 41 of Set 12 | labytnangi
# Processing Record 42 of Set 12 | pemangkat
# Processing Record 43 of Set 12 | banjar
# Processing Record 44 of Set 12 | leh
# Processing Record 45 of Set 12 | santa cruz
# Processing Record 46 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 47 of Set 12 | rochegda
# Processing Record 48 of Set 12 | normal
# Processing Record 49 of Set 12 | thinadhoo
# Processing Record 50 of Set 12 | kendari
# Processing Record 1 of Set 13 | male
# Processing Record 2 of Set 13 | astipalaia
# City not found. Skipping...
# Processing Record 3 of Set 13 | waipawa
# Processing Record 4 of Set 13 | puerto colombia
# Processing Record 5 of Set 13 | naze
# Processing Record 6 of Set 13 | luderitz
# Processing Record 7 of Set 13 | point pedro
# Processing Record 8 of Set 13 | portland
# Processing Record 9 of Set 13 | tashtyp
# Processing Record 10 of Set 13 | joigny
# Processing Record 11 of Set 13 | omboue
# Processing Record 12 of Set 13 | porto belo
# Processing Record 13 of Set 13 | sao miguel dos campos
# Processing Record 14 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 13 | ishigaki
# Processing Record 16 of Set 13 | arak
# Processing Record 17 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 18 of Set 13 | sebring
# Processing Record 19 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 13 | nha trang
# Processing Record 21 of Set 13 | shitanjing
# Processing Record 22 of Set 13 | harlingen
# Processing Record 23 of Set 13 | kholm
# Processing Record 24 of Set 13 | blacksburg
# Processing Record 25 of Set 13 | ruangwa
# Processing Record 26 of Set 13 | palana
# Processing Record 27 of Set 13 | leshukonskoye
# Processing Record 28 of Set 13 | hwange
# Processing Record 29 of Set 13 | maceio
# Processing Record 30 of Set 13 | edirne
# Processing Record 31 of Set 13 | neiafu
# Processing Record 32 of Set 13 | luhacovice
# Processing Record 33 of Set 13 | balarampur
# Processing Record 34 of Set 13 | bone
# Processing Record 35 of Set 13 | aswan
# Processing Record 36 of Set 13 | gimli
# Processing Record 37 of Set 13 | waddan
# Processing Record 38 of Set 13 | adeje
# Processing Record 39 of Set 13 | dickinson
# Processing Record 40 of Set 13 | lavrentiya
# Processing Record 41 of Set 13 | carballo
# Processing Record 42 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 13 | wanaka
# Processing Record 44 of Set 13 | enterprise
# Processing Record 45 of Set 13 | altay
# Processing Record 46 of Set 13 | prainha
# Processing Record 47 of Set 13 | moose factory
# Processing Record 48 of Set 13 | hofn
# Processing Record 49 of Set 13 | mugur-aksy
# Processing Record 50 of Set 13 | zanjan
# Processing Record 1 of Set 14 | kaya
# Processing Record 2 of Set 14 | yeppoon
# Processing Record 3 of Set 14 | atessa
# Processing Record 4 of Set 14 | falam
# Processing Record 5 of Set 14 | sambava
# Processing Record 6 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 14 | mbandaka
# Processing Record 8 of Set 14 | mae sot
# Processing Record 9 of Set 14 | mogadishu
# Processing Record 10 of Set 14 | naliya
# Processing Record 11 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 12 of Set 14 | anloga
# Processing Record 13 of Set 14 | copiapo
# Processing Record 14 of Set 14 | oyon
# Processing Record 15 of Set 14 | kongolo
# Processing Record 16 of Set 14 | itigi
# Processing Record 17 of Set 14 | bubaque
# Processing Record 18 of Set 14 | beruwala
# Processing Record 19 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 20 of Set 14 | minnedosa
# Processing Record 21 of Set 14 | lucapa
# Processing Record 22 of Set 14 | hay river
# Processing Record 23 of Set 14 | vigrestad
# Processing Record 24 of Set 14 | winona
# Processing Record 25 of Set 14 | te anau
# Processing Record 26 of Set 14 | mana
# Processing Record 27 of Set 14 | hobyo
# Processing Record 28 of Set 14 | road town
# Processing Record 29 of Set 14 | mackay
# Processing Record 30 of Set 14 | dombasle-sur-meurthe
# Processing Record 31 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 14 | koshurnikovo
# Processing Record 33 of Set 14 | toamasina
# Processing Record 34 of Set 14 | ussel
# Processing Record 35 of Set 14 | meinung
# City not found. Skipping...
# Processing Record 36 of Set 14 | hirna
# Processing Record 37 of Set 14 | lere
# Processing Record 38 of Set 14 | batticaloa
# Processing Record 39 of Set 14 | rawson
# Processing Record 40 of Set 14 | north platte
# Processing Record 41 of Set 14 | nago
# Processing Record 42 of Set 14 | wairoa
# Processing Record 43 of Set 14 | kerrville
# Processing Record 44 of Set 14 | ereymentau
# Processing Record 45 of Set 14 | talcahuano
# Processing Record 46 of Set 14 | northam
# Processing Record 47 of Set 14 | lusambo
# Processing Record 48 of Set 14 | inowroclaw
# Processing Record 49 of Set 14 | lady frere
# Processing Record 50 of Set 14 | jackson
# Processing Record 1 of Set 15 | tateyama
# Processing Record 2 of Set 15 | okhansk
# Processing Record 3 of Set 15 | qaqortoq
# Processing Record 4 of Set 15 | newport
# Processing Record 5 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 6 of Set 15 | pinheiro
# Processing Record 7 of Set 15 | cowra
# Processing Record 8 of Set 15 | kloulklubed
# Processing Record 9 of Set 15 | salina cruz
# Processing Record 10 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 15 | gamba
# Processing Record 12 of Set 15 | shobara
# Processing Record 13 of Set 15 | molnlycke
# Processing Record 14 of Set 15 | nouadhibou
# Processing Record 15 of Set 15 | zhanaozen
# Processing Record 16 of Set 15 | mega
# Processing Record 17 of Set 15 | tabou
# Processing Record 18 of Set 15 | lixourion
# Processing Record 19 of Set 15 | caravelas
# Processing Record 20 of Set 15 | buala
# Processing Record 21 of Set 15 | alzamay
# Processing Record 22 of Set 15 | chakradharpur
# Processing Record 23 of Set 15 | rio gallegos
# Processing Record 24 of Set 15 | olindina
# Processing Record 25 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 15 | solton
# Processing Record 27 of Set 15 | oistins
# Processing Record 28 of Set 15 | makokou
# Processing Record 29 of Set 15 | marawi
# Processing Record 30 of Set 15 | kashan
# Processing Record 31 of Set 15 | novobelokatay
# Processing Record 32 of Set 15 | luau
# Processing Record 33 of Set 15 | ise
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     41.02        87           0
# 1        Bethel  41.3712  -73.4140     50.68        90         100
# 2         Vaini -21.2000 -175.2000     77.16       100          75
# 3     Busselton -33.6500  115.3333     65.44        59          65
# 4         Pevek  69.7008  170.3133     -3.30        98         100
# 5          Ayan  56.4500  138.1667     23.25        85         100
# 6        Avarua -21.2078 -159.7750     80.65        83          40
# 7          Liku  -0.7275  119.8922     75.34        90         100
# 8      Klaksvik  62.2266   -6.5890     38.32        73         100
# 9    Bredasdorp -34.5322   20.0403     63.25        54          78
#
#    Wind Speed Country          Current Description
# 0        4.61      CL                    clear sky
# 1       11.50      US              overcast clouds
# 2        3.44      TO  light intensity shower rain
# 3        4.09      AU                broken clouds
# 4        8.52      RU              overcast clouds
# 5        4.54      RU              overcast clouds
# 6        5.75      CK             scattered clouds
# 7        1.79      ID              overcast clouds
# 8       34.00      FO              overcast clouds
# 9       10.33      ZA                broken clouds

# %%
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description" ]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     41.02        87           0
# 1        Bethel      US  41.3712  -73.4140     50.68        90         100
# 2         Vaini      TO -21.2000 -175.2000     77.16       100          75
# 3     Busselton      AU -33.6500  115.3333     65.44        59          65
# 4         Pevek      RU  69.7008  170.3133     -3.30        98         100
# 5          Ayan      RU  56.4500  138.1667     23.25        85         100
# 6        Avarua      CK -21.2078 -159.7750     80.65        83          40
# 7          Liku      ID  -0.7275  119.8922     75.34        90         100
# 8      Klaksvik      FO  62.2266   -6.5890     38.32        73         100
# 9    Bredasdorp      ZA -34.5322   20.0403     63.25        54          78
#
#    Wind Speed          Current Description
# 0        4.61                    clear sky
# 1       11.50              overcast clouds
# 2        3.44  light intensity shower rain
# 3        4.09                broken clouds
# 4        8.52              overcast clouds
# 5        4.54              overcast clouds
# 6        5.75             scattered clouds
# 7        1.79              overcast clouds
# 8       34.00              overcast clouds
# 9       10.33                broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
